# %% [markdown]
# # Assignment 1 Report

# %% [markdown]
# This is an outline for your report to ease the amount of work required to create your report. Jupyter notebook supports markdown, and I recommend you to check out this [cheat sheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet). If you are not familiar with markdown.
#
# Before delivery, **remember to convert this file to PDF**. You can do it in two ways:
# 1. Print the webpage (ctrl+P or cmd+P)
# 2. Export with latex. This is somewhat more difficult, but you'll get somehwat of a "prettier" PDF. Go to File -> Download as -> PDF via LaTeX. You might have to install nbconvert and pandoc through conda; `conda install nbconvert pandoc`.

# %% [markdown]
# # Task 1

# %% [markdown]
# ## task 1a)
#
# ![image.png](attachment:ee836cee-5df6-42fb-bc12-e28df001549b.png)

# %% [markdown]
# ## task 1b)
#
# ![image.png](attachment:156af0e4-ca8c-4a91-b1da-30b14ba5bfa4.png)

# %% [markdown]
# # Task 2

# %%
#%run task2a.py

# %%
# %run task2.py
# Out:
# Train shape: X: (4005, 784), Y: (4005, 1)
# Validation shape: X: (2042, 784), Y: (2042, 1)
# Final Train Cross Entropy Loss: 0.08192874547657233
# Final Validation Cross Entropy Loss: 0.07586408210182093
# Train accuracy: 0.9727840199750312
# Validation accuracy: 0.9745347698334965

# %% [markdown]
# ## Task 2b)
#
# "![](task2b_binary_train_loss.png)"

# %% [markdown]
# ## Task 2c)
#
# "![](task2b_binary_train_accuracy.png)"

# %% [markdown]
# ## Task 2d)
# Early stopping kiks in after about 16 epochs

# %% [markdown]
# ## Task 2e)
# generaly shuffling will give less overfitting and a more general model
# ![](task2e_train_accuracy_shuffle_difference.png)

# %% [markdown]
# # Task 3

# %%
#%run task3a.py

# %%
#%run task3.py

# %% [markdown]
# ## Task 3b)
# ![image.png](attachment:12e7a6c6-5a35-4de1-892d-631bb0fbf1bf.png)

# %% [markdown]
# ## Task 3c)
# ![image.png](attachment:2078eaed-76bb-4546-a04f-70866355041f.png)

# %% [markdown]
# ## Task 3d)
# There is a small gap between validation and trainging accuracy because of overfitting, abd the gap in increasing

# %% [markdown]
# # Task 4

# %% [markdown]
# ## Task 4a)
# ![image.png](attachment:3847df54-b9aa-46fb-82bb-d11ce77bc878.png)
# Fill in image of hand-written notes which are easy to read, or latex equations here

# %% [markdown]
# ## Task 4b)
# The model with L=1 is less noisy because it is less complex and and less overfitted
#
# ![image.png](attachment:1d7a4abc-f8cc-492d-ba58-7b57969a66ea.png)
# Top row L=0, bottom row L=1

# %% [markdown]
# ## Task 4c)
# ![image.png](attachment:b328b1b5-5580-4698-a5cd-c6c843e40d88.png)

# %% [markdown]
# ## Task 4d)
# any regulirazation makes the newtwork less complex, and more generalized. thus loosing some accuracy compared to the ones without.

# %% [markdown]
# ## Task 4e)
# ![image.png](attachment:d0ef73ae-7273-4b1c-bb0f-8c29a8d67e4e.png)

# %%
# %run create_submission_zip.py
# Out:
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\TDT4265\TDT4265_StarterCode\assignment1\create_submission_zip.py in <module>
#      46     for filename, extensions in files_to_include.items():
#      47         filepath = select_file(filename, extensions)
# ---> 48         assert os.path.isfile(filepath),\
#      49             f"Did not find path: {filepath}"
#      50         fp.write(filepath)
#
# AssertionError: Did not find path: mnist.py.py
