# %% [markdown]
# # Assignment 2 Report

# %% [markdown]
# # Task 1

# %%
# %load_ext autoreload
# %autoreload 2
#%run task2a.py
#%run task2.py
#%run task3.py
#%run task4c.py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## task 1a)
#
# ![image.png](attachment:208f825e-2317-4bf1-b1b0-d05a1ef8c381.png)

# %% [markdown]
# # Task 2

# %%
from task2a import mean_X
from task2a import std_X
X, Y, *_ = utils.load_full_mnist()
print("Mean:",mean_X(X))
print("Std: ",std_X(X))
# Out:
# Train shape: X: (20000, 784), Y: (20000, 1)
# Validation shape: X: (10000, 784), Y: (10000, 1)
# Mean: 33.55274553571429
# Std:  78.87550070784701

# %% [markdown]
# ## Task 2a)
# ![image.png](attachment:2f62eba5-858f-4fe0-9300-005374fc0f68.png)

# %% [markdown]
# ## Task 2c)
# ![task2c_train_loss.png](attachment:4b0ec9ac-0abe-4420-97f8-2ce38acce39a.png)

# %% [markdown]
# ## Task 2d)
# ![image.png](attachment:32ada5db-e2e0-496c-a0e1-a8d08ecfc957.png)

# %% [markdown]
# # Task 3

# %% [markdown]
# ![image.png](attachment:9638dd21-caa2-4dfd-9624-c42c7003a111.png)
# ![image.png](attachment:8c6770db-7fbb-4b96-b29f-17201a340550.png)

# %% [markdown]
# Improved wheight init gave the highest step in preformance but still same number of epochs
#
# Sigmoid added a bit more preformance and early stopping came into effect much earlier
#
# Momentum had even faster convergance speed and had the fastest earlt stop

# %% [markdown]
# # Task 4

# %% [markdown]
# ## Task 4a)
#
# ![image.png](attachment:55e48dbf-b6ed-4265-a795-a429ee3107dc.png)

# %% [markdown]
# To low number of hidden nodes could make the network to simple and you loose preformance

# %% [markdown]
# ## Task 4b)
#
# ![image.png](attachment:10bda2f8-63e1-4f51-aebe-5f9f7bcb60cf.png)

# %% [markdown]
# To many nodes could result in overfitting and more paramaters to train

# %% [markdown]
# ## Task 4d)
# ![image.png](attachment:a43c2b23-ad5c-41cd-90be-2dd36bd5223c.png)
#
# ![image.png](attachment:1d02015b-5347-43ea-ab0d-b6364d200419.png)

# %% [markdown]
# The two networks compare well both preform equally well

# %% [markdown]
# ## Task 4e)
# ![image.png](attachment:712ef526-39fd-4a75-9983-b2d91be314e3.png)

# %% [markdown]
# ## Task 4f)
# ![image.png](attachment:43321b67-8777-4b68-b6d3-84c5a2acabf9.png)
