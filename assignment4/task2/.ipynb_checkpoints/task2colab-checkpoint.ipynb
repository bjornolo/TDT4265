# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Insert the directory
import sys
sys.path.insert(0,'/content/drive/MyDrive/Colab/Assignment4/task2/')

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import task2
import predicted_boxes
from tests import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-141-d618024b435c> in <module>
#       1 import task2
# ----> 2 import predicted_boxes
#       3 from tests import *
#
# ModuleNotFoundError: No module named 'predicted_boxes'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
ground_truth_boxes = read_ground_truth_boxes()
predicted_boxes = read_predicted_boxes()
mean_average_precision(ground_truth_boxes, predicted_boxes)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-139-605a6c0bcd67> in <module>
# ----> 1 ground_truth_boxes = read_ground_truth_boxes()
#       2 predicted_boxes = read_predicted_boxes()
#       3 mean_average_precision(ground_truth_boxes, predicted_boxes)
#
# /content/drive/MyDrive/Colab/Assignment4/task2/tools.py in read_ground_truth_boxes()
#      29
#      30 def read_ground_truth_boxes():
# ---> 31     json_file = read_json_file("ground_truth_boxes.json")
#      32     for image_id in json_file.keys():
#      33         boxes = np.array(json_file[image_id])
#
# /content/drive/MyDrive/Colab/Assignment4/task2/tools.py in read_json_file(filepath)
#       9
#      10 def read_json_file(filepath):
# ---> 11     assert os.path.isfile(filepath), "Did not find filepath. \
#      12                      I looked in: {}".format(os.path.abspath(filepath))
#      13     with open(filepath, "r") as to_read:
#
# AssertionError: Did not find filepath.                      I looked in: /content/ground_truth_boxes.json
